# %%
import pandas as pd

# %%
eng=pd.DataFrame({'name_1':'Adam Robin Mike Andrew Jack Aaron'.split(' '),
                    'eng':[50,41,24,18,30,21]})
eng
# Out:
#    name_1  eng
# 0    Adam   50
# 1   Robin   41
# 2    Mike   24
# 3  Andrew   18
# 4    Jack   30
# 5   Aaron   21

# %%
math=pd.DataFrame({'name_2':['Adam', 'Adam', 'Dennis', 'Aaron', 'Andrew', 'Jack', 'Mark'],
                  'math':[10,15,42,70,2,22,11]})
math
# Out:
#    name_2  math
# 0    Adam    10
# 1    Adam    15
# 2  Dennis    42
# 3   Aaron    70
# 4  Andrew     2
# 5    Jack    22
# 6    Mark    11

# %%
#inner_merge
pd.merge(left=eng,right=math, how='inner', left_on='name_1', right_on='name_2', indicator=True)
# Out:
#    name_1  eng  name_2  math _merge
# 0    Adam   50    Adam    10   both
# 1    Adam   50    Adam    15   both
# 2  Andrew   18  Andrew     2   both
# 3    Jack   30    Jack    22   both
# 4   Aaron   21   Aaron    70   both

# %%
#outer merge
pd.merge(left=eng, right=math, how='outer',left_on='name_1', right_on='name_2', indicator='True')
# Out:
#    name_1   eng  name_2  math        True
# 0    Adam  50.0    Adam  10.0        both
# 1    Adam  50.0    Adam  15.0        both
# 2   Robin  41.0     NaN   NaN   left_only
# 3    Mike  24.0     NaN   NaN   left_only
# 4  Andrew  18.0  Andrew   2.0        both
# 5    Jack  30.0    Jack  22.0        both
# 6   Aaron  21.0   Aaron  70.0        both
# 7     NaN   NaN  Dennis  42.0  right_only
# 8     NaN   NaN    Mark  11.0  right_only

# %%
#left merge
pd.merge(left=eng, right=math, how='left', left_on='name_1', right_on='name_2', indicator='True')
# Out:
#    name_1  eng  name_2  math       True
# 0    Adam   50    Adam  10.0       both
# 1    Adam   50    Adam  15.0       both
# 2   Robin   41     NaN   NaN  left_only
# 3    Mike   24     NaN   NaN  left_only
# 4  Andrew   18  Andrew   2.0       both
# 5    Jack   30    Jack  22.0       both
# 6   Aaron   21   Aaron  70.0       both

# %%
#right merge
pd.merge(left=eng, right=math, how='right', left_on='name_1', right_on='name_2', indicator='True')
# Out:
#    name_1   eng  name_2  math        True
# 0    Adam  50.0    Adam    10        both
# 1    Adam  50.0    Adam    15        both
# 2     NaN   NaN  Dennis    42  right_only
# 3   Aaron  21.0   Aaron    70        both
# 4  Andrew  18.0  Andrew     2        both
# 5    Jack  30.0    Jack    22        both
# 6     NaN   NaN    Mark    11  right_only

# %%
x=pd.concat([eng,math], sort=False, axis=0, keys=['a','b'])
x
# Out:
#      name_1   eng  name_2  math
# a 0    Adam  50.0     NaN   NaN
#   1   Robin  41.0     NaN   NaN
#   2    Mike  24.0     NaN   NaN
#   3  Andrew  18.0     NaN   NaN
#   4    Jack  30.0     NaN   NaN
#   5   Aaron  21.0     NaN   NaN
# b 0     NaN   NaN    Adam  10.0
#   1     NaN   NaN    Adam  15.0
#   2     NaN   NaN  Dennis  42.0
#   3     NaN   NaN   Aaron  70.0
#   4     NaN   NaN  Andrew   2.0
#   5     NaN   NaN    Jack  22.0
#   6     NaN   NaN    Mark  11.0

# %%
x=pd.concat([eng,math], axis=1, sort=False, join='outer', keys=['a','b'])
x
# Out:
#         a             b
#    name_1   eng  name_2 math
# 0    Adam  50.0    Adam   10
# 1   Robin  41.0    Adam   15
# 2    Mike  24.0  Dennis   42
# 3  Andrew  18.0   Aaron   70
# 4    Jack  30.0  Andrew    2
# 5   Aaron  21.0    Jack   22
# 6     NaN   NaN    Mark   11

# %%
x.loc['a']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9564/3342034315.py in <module>
# ----> 1 x.loc['a']
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1162         # fall thru to straight lookup
#    1163         self._validate_key(key, axis)
# -> 1164         return self._get_label(key, axis=axis)
#    1165
#    1166     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexing.py in _get_label(self, label, axis)
#    1111     def _get_label(self, label, axis: int):
#    1112         # GH#5667 this will fail if the label is not present in the axis.
# -> 1113         return self.obj.xs(label, axis=axis)
#    1114
#    1115     def _handle_lowerdim_multi_index_axis0(self, tup: tuple):
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3771                 raise TypeError(f"Expected label or tuple of labels, got {key}") from e
#    3772         else:
# -> 3773             loc = index.get_loc(key)
#    3774
#    3775             if isinstance(loc, np.ndarray):
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     386                 except ValueError as err:
#     387                     raise KeyError(key) from err
# --> 388             raise KeyError(key)
#     389         return super().get_loc(key, method=method, tolerance=tolerance)
#     390
#
# KeyError: 'a'

# %%
x.loc['b']
# Out:
#   name_1  eng  name_2  math
# 0    NaN  NaN    Adam  10.0
# 1    NaN  NaN    Adam  15.0
# 2    NaN  NaN  Dennis  42.0
# 3    NaN  NaN   Aaron  70.0
# 4    NaN  NaN  Andrew   2.0
# 5    NaN  NaN    Jack  22.0
# 6    NaN  NaN    Mark  11.0

# %%
eng.append(math, sort=False)
# Out:
#    name_1   eng  name_2  math
# 0    Adam  50.0     NaN   NaN
# 1   Robin  41.0     NaN   NaN
# 2    Mike  24.0     NaN   NaN
# 3  Andrew  18.0     NaN   NaN
# 4    Jack  30.0     NaN   NaN
# 5   Aaron  21.0     NaN   NaN
# 0     NaN   NaN    Adam  10.0
# 1     NaN   NaN    Adam  15.0
# 2     NaN   NaN  Dennis  42.0
# 3     NaN   NaN   Aaron  70.0
# 4     NaN   NaN  Andrew   2.0
# 5     NaN   NaN    Jack  22.0
# 6     NaN   NaN    Mark  11.0

# %%
math.append(eng, sort=False)
