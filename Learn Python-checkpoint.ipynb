# %% [markdown]
# Import the necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Import the necessary data frames

# %%
cab= pd.read_csv('C:/Users/Daisy/Desktop/data glacier/Cab_Data.csv')
city=pd.read_csv('C:/Users/Daisy/Desktop/data glacier/City.csv')
customer= pd.read_csv('C:/Users/Daisy/Desktop/data glacier/Customer_ID.csv')
transaction =pd.read_csv('C:/Users/Daisy/Desktop/data glacier/Transaction_ID.csv')

# %%
cab.head()
# Out:
#    Transaction ID  Date of Travel   Company        City  KM Travelled  \
# 0        10000011           42377  Pink Cab  ATLANTA GA         30.45
# 1        10000012           42375  Pink Cab  ATLANTA GA         28.62
# 2        10000013           42371  Pink Cab  ATLANTA GA          9.04
# 3        10000014           42376  Pink Cab  ATLANTA GA         33.17
# 4        10000015           42372  Pink Cab  ATLANTA GA          8.73
#
#    Price Charged  Cost of Trip
# 0         370.95       313.635
# 1         358.52       334.854
# 2         125.20        97.632
# 3         377.40       351.602
# 4         114.62        97.776

# %%
city.head()
# Out:
#              City   Population      Users
# 0     NEW YORK NY   8,405,837    302,149
# 1      CHICAGO IL   1,955,130    164,468
# 2  LOS ANGELES CA   1,595,037    144,132
# 3        MIAMI FL   1,339,155     17,675
# 4  SILICON VALLEY   1,177,609     27,247

# %%
customer.head()
# Out:
#    Customer ID Gender  Age  Income (USD/Month)
# 0        29290   Male   28               10813
# 1        27703   Male   27                9237
# 2        28712   Male   53               11242
# 3        28020   Male   23               23327
# 4        27182   Male   33                8536

# %%
transaction.head()
# Out:
#    Transaction ID  Customer ID Payment_Mode
# 0        10000011        29290         Card
# 1        10000012        27703         Card
# 2        10000013        28712         Cash
# 3        10000014        28020         Cash
# 4        10000015        27182         Card

# %%
#Get the number of rows, columns for each dataset
print ("cab",cab.shape)
print ("transaction",transaction.shape)
print ("customer",customer.shape)
# Out:
# cab (359392, 7)
# transaction (440098, 3)
# customer (49171, 4)

# %%
#Exploration on data relationships:Correlation
#Table below shows a high correlation between the 'price charged' and the 'cost of the trip' and 'KM travelled'
cab_corr=cab.corr()
cab_corr
# Out:
#                 Transaction ID  Date of Travel  KM Travelled  Price Charged  \
# Transaction ID        1.000000        0.993030     -0.001429      -0.052902
# Date of Travel        0.993030        1.000000     -0.001621      -0.055559
# KM Travelled         -0.001429       -0.001621      1.000000       0.835753
# Price Charged        -0.052902       -0.055559      0.835753       1.000000
# Cost of Trip         -0.003462       -0.004484      0.981848       0.859812
#
#                 Cost of Trip
# Transaction ID     -0.003462
# Date of Travel     -0.004484
# KM Travelled        0.981848
# Price Charged       0.859812
# Cost of Trip        1.000000

# %% [markdown]
# The next cell visualizes the heatmap for all the variablesin the data set.
# From the scale on the right,color red os at 0 meaning it represents weak correlation.
# color blue is at 1 meaning it represents strong correlation.
# therefore we can see a strong correlation between Price charged and the KM travelled and the cost of the trip.

# %%
#Visualize the correlation matrix using a heatmap
cab_hm= sns.heatmap(cab_corr
                   ,cmap=sns.diverging_palette(20, 220, n=200))
cab_hm
# Out:
# <AxesSubplot:>

# %% [markdown]
# The next cell will be merging two data sets;Transaction_ID and Cab_Data. the process will be carried out with a full outer merge because the two datasets have a common column:'Transaction ID'.A full outer merge combines both tables without losing any columns.

# %%
new=pd.merge(cab, transaction)
new.head()
# Out:
#    Transaction ID  Date of Travel   Company        City  KM Travelled  \
# 0        10000011           42377  Pink Cab  ATLANTA GA         30.45
# 1        10000012           42375  Pink Cab  ATLANTA GA         28.62
# 2        10000013           42371  Pink Cab  ATLANTA GA          9.04
# 3        10000014           42376  Pink Cab  ATLANTA GA         33.17
# 4        10000015           42372  Pink Cab  ATLANTA GA          8.73
#
#    Price Charged  Cost of Trip  Customer ID Payment_Mode
# 0         370.95       313.635        29290         Card
# 1         358.52       334.854        27703         Card
# 2         125.20        97.632        28712         Cash
# 3         377.40       351.602        28020         Cash
# 4         114.62        97.776        27182         Card

# %%
new.tail()
# Out:
#         Transaction ID  Date of Travel     Company           City  \
# 359387        10440101           43108  Yellow Cab  WASHINGTON DC
# 359388        10440104           43104  Yellow Cab  WASHINGTON DC
# 359389        10440105           43105  Yellow Cab  WASHINGTON DC
# 359390        10440106           43105  Yellow Cab  WASHINGTON DC
# 359391        10440107           43102  Yellow Cab  WASHINGTON DC
#
#         KM Travelled  Price Charged  Cost of Trip  Customer ID Payment_Mode
# 359387          4.80          69.24       63.3600        52392         Cash
# 359388          8.40         113.75      106.8480        53286         Cash
# 359389         27.75         437.07      349.6500        52265         Cash
# 359390          8.80         146.19      114.0480        52175         Card
# 359391         12.76         191.58      177.6192        52917         Card

# %% [markdown]
# We find correlationof the merged dataset

# %%
new.corr(method='spearman')
# Out:
#                 Transaction ID  Date of Travel  KM Travelled  Price Charged  \
# Transaction ID        1.000000        0.995275     -0.001470      -0.040401
# Date of Travel        0.995275        1.000000     -0.001541      -0.041547
# KM Travelled         -0.001470       -0.001541      1.000000       0.892958
# Price Charged        -0.040401       -0.041547      0.892958       1.000000
# Cost of Trip         -0.003537       -0.004246      0.984546       0.913581
# Customer ID          -0.020391       -0.019489      0.000428      -0.204821
#
#                 Cost of Trip  Customer ID
# Transaction ID     -0.003537    -0.020391
# Date of Travel     -0.004246    -0.019489
# KM Travelled        0.984546     0.000428
# Price Charged       0.913581    -0.204821
# Cost of Trip        1.000000    -0.009639
# Customer ID        -0.009639     1.000000

# %%
customer.corr(method='pearson')
# Out:
#                     Customer ID       Age  Income (USD/Month)
# Customer ID            1.000000 -0.006749           -0.006911
# Age                   -0.006749  1.000000            0.000156
# Income (USD/Month)    -0.006911  0.000156            1.000000

# %%
customer.corr(method='spearman')
# Out:
#                     Customer ID       Age  Income (USD/Month)
# Customer ID            1.000000 -0.004956           -0.007843
# Age                   -0.004956  1.000000            0.000552
# Income (USD/Month)    -0.007843  0.000552            1.000000

# %% [markdown]
# Search for and remove null variables

# %%
nulls=new.isnull()
nulls
# Out:
#         Transaction ID  Date of Travel  Company   City  KM Travelled  \
# 0                False           False    False  False         False
# 1                False           False    False  False         False
# 2                False           False    False  False         False
# 3                False           False    False  False         False
# 4                False           False    False  False         False
# ...                ...             ...      ...    ...           ...
# 359387           False           False    False  False         False
# 359388           False           False    False  False         False
# 359389           False           False    False  False         False
# 359390           False           False    False  False         False
# 359391           False           False    False  False         False
#
#         Price Charged  Cost of Trip  Customer ID  Payment_Mode
# 0               False         False        False         False
# 1               False         False        False         False
# 2               False         False        False         False
# 3               False         False        False         False
# 4               False         False        False         False
# ...               ...           ...          ...           ...
# 359387          False         False        False         False
# 359388          False         False        False         False
# 359389          False         False        False         False
# 359390          False         False        False         False
# 359391          False         False        False         False
#
# [359392 rows x 9 columns]

# %%
new.dropna()
# Out:
#         Transaction ID  Date of Travel     Company           City  \
# 0             10000011           42377    Pink Cab     ATLANTA GA
# 1             10000012           42375    Pink Cab     ATLANTA GA
# 2             10000013           42371    Pink Cab     ATLANTA GA
# 3             10000014           42376    Pink Cab     ATLANTA GA
# 4             10000015           42372    Pink Cab     ATLANTA GA
# ...                ...             ...         ...            ...
# 359387        10440101           43108  Yellow Cab  WASHINGTON DC
# 359388        10440104           43104  Yellow Cab  WASHINGTON DC
# 359389        10440105           43105  Yellow Cab  WASHINGTON DC
# 359390        10440106           43105  Yellow Cab  WASHINGTON DC
# 359391        10440107           43102  Yellow Cab  WASHINGTON DC
#
#         KM Travelled  Price Charged  Cost of Trip  Customer ID Payment_Mode  \
# 0              30.45         370.95      313.6350        29290         Card
# 1              28.62         358.52      334.8540        27703         Card
# 2               9.04         125.20       97.6320        28712         Cash
# 3              33.17         377.40      351.6020        28020         Cash
# 4               8.73         114.62       97.7760        27182         Card
# ...              ...            ...           ...          ...          ...
# 359387          4.80          69.24       63.3600        52392         Cash
# 359388          8.40         113.75      106.8480        53286         Cash
# 359389         27.75         437.07      349.6500        52265         Cash
# 359390          8.80         146.19      114.0480        52175         Card
# 359391         12.76         191.58      177.6192        52917         Card
#
#          profit
# 0       57.3150
# 1       23.6660
# 2       27.5680
# 3       25.7980
# 4       16.8440
# ...         ...
# 359387   5.8800
# 359388   6.9020
# 359389  87.4200
# 359390  32.1420
# 359391  13.9608
#
# [359392 rows x 10 columns]

# %%
new.describe()
# Out:
#        Transaction ID  Date of Travel   KM Travelled  Price Charged  \
# count    3.593920e+05   359392.000000  359392.000000  359392.000000
# mean     1.022076e+07    42964.067998      22.567254     423.443311
# std      1.268058e+05      307.467197      12.233526     274.378911
# min      1.000001e+07    42371.000000       1.900000      15.600000
# 25%      1.011081e+07    42697.000000      12.000000     206.437500
# 50%      1.022104e+07    42988.000000      22.440000     386.360000
# 75%      1.033094e+07    43232.000000      32.960000     583.660000
# max      1.044011e+07    43465.000000      48.000000    2048.030000
#
#         Cost of Trip    Customer ID         profit
# count  359392.000000  359392.000000  359392.000000
# mean      286.190113   19191.652115     137.253198
# std       157.993661   21012.412463     160.311840
# min        19.000000       1.000000    -220.060000
# 25%       151.200000    2705.000000      28.012000
# 50%       282.480000    7459.000000      81.962000
# 75%       413.683200   36078.000000     190.030000
# max       691.200000   60000.000000    1463.966000

# %% [markdown]
# Add a new column 'profit' to represent the profit made per trip

# %%
new['profit']= new['Price Charged']-new['Cost of Trip']
new.head()
# Out:
#    Transaction ID  Date of Travel   Company        City  KM Travelled  \
# 0        10000011           42377  Pink Cab  ATLANTA GA         30.45
# 1        10000012           42375  Pink Cab  ATLANTA GA         28.62
# 2        10000013           42371  Pink Cab  ATLANTA GA          9.04
# 3        10000014           42376  Pink Cab  ATLANTA GA         33.17
# 4        10000015           42372  Pink Cab  ATLANTA GA          8.73
#
#    Price Charged  Cost of Trip  Customer ID Payment_Mode  profit
# 0         370.95       313.635        29290         Card  57.315
# 1         358.52       334.854        27703         Card  23.666
# 2         125.20        97.632        28712         Cash  27.568
# 3         377.40       351.602        28020         Cash  25.798
# 4         114.62        97.776        27182         Card  16.844

# %%
Pink_cab_profit=new.query("Company == 'Pink Cab'")['profit'].sum()   
Pink_cab_profit
# Out:
# 5307328.321

# %%
Yellow_cab_profit= new.query("Company == 'Yellow cab'")['profit'].sum()
Yellow_cab_profit
# Out:
# 0.0

# %%
cab.head()
# Out:
#    Transaction ID  Date of Travel   Company        City  KM Travelled  \
# 0        10000011           42377  Pink Cab  ATLANTA GA         30.45
# 1        10000012           42375  Pink Cab  ATLANTA GA         28.62
# 2        10000013           42371  Pink Cab  ATLANTA GA          9.04
# 3        10000014           42376  Pink Cab  ATLANTA GA         33.17
# 4        10000015           42372  Pink Cab  ATLANTA GA          8.73
#
#    Price Charged  Cost of Trip
# 0         370.95       313.635
# 1         358.52       334.854
# 2         125.20        97.632
# 3         377.40       351.602
# 4         114.62        97.776

# %%
print(cab.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 359392 entries, 0 to 359391
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Transaction ID  359392 non-null  int64
#  1   Date of Travel  359392 non-null  int64
#  2   Company         359392 non-null  object
#  3   City            359392 non-null  object
#  4   KM Travelled    359392 non-null  float64
#  5   Price Charged   359392 non-null  float64
#  6   Cost of Trip    359392 non-null  float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 19.2+ MB
# None

# %%
print(cab.shape)
# Out:
# (359392, 7)

# %%
print(cab.columns)
# Out:
# Index(['Transaction ID', 'Date of Travel', 'Company', 'City', 'KM Travelled',
#        'Price Charged', 'Cost of Trip'],
#       dtype='object')

# %%
cab.loc[100]
# Out:
# Transaction ID          10000111
# Date of Travel             42374
# Company                 Pink Cab
# City              LOS ANGELES CA
# KM Travelled               34.68
# Price Charged             720.24
# Cost of Trip              398.82
# Name: 100, dtype: object

# %%
Date_of_Travel=cab.loc[:,'Date of Travel']
Date_of_Travel.head(10)
# Out:
# 0    42377
# 1    42375
# 2    42371
# 3    42376
# 4    42372
# 5    42376
# 6    42372
# 7    42376
# 8    42381
# 9    42375
# Name: Date of Travel, dtype: int64

# %%
distance_cost=cab.groupby([2])['Cost of Trip'].sum()
dist=distance_cost.head(50)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-dd7bf5e4ad06> in <module>
# ----> 1 distance_cost=cab.groupby([2])['Cost of Trip'].sum()
#       2 dist=distance_cost.head(50)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6715         axis = self._get_axis_number(axis)
#    6716
# -> 6717         return DataFrameGroupBy(
#    6718             obj=self,
#    6719             keys=by,
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     558             from pandas.core.groupby.grouper import get_grouper
#     559
# --> 560             grouper, exclusions, obj = get_grouper(
#     561                 obj,
#     562                 keys,
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\grouper.py in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     809                 in_axis, name, level, gpr = False, None, gpr, None
#     810             else:
# --> 811                 raise KeyError(gpr)
#     812         elif isinstance(gpr, Grouper) and gpr.key is not None:
#     813             # Add key to exclusions
#
# KeyError: 2

# %%
dist.plot()

# %%
distance_cost=cab.groupby(['Date of Travel'])[['Price Charged','Cost of Trip']].sum()
distance_cost.head(15)
# Out:
#                 Price Charged  Cost of Trip
# Date of Travel
# 01/01/2017          430286.45   257023.9988
# 01/01/2018          146397.20   103399.8286
# 01/02/2016           46358.25    28827.0040
# 01/02/2017           46430.98    31759.8294
# 01/02/2018           67017.44    46393.6298
# 01/03/2016           48349.17    31599.4268
# 01/03/2017           58111.11    38893.8842
# 01/03/2018           64085.05    46194.2172
# 01/04/2016           69614.49    49006.7510
# 01/04/2017           80561.87    53019.5332
# 01/04/2018           53901.39    39653.8918
# 01/05/2016          220366.66   123711.9744
# 01/05/2017           72881.56    48832.5254
# 01/05/2018           59640.14    38971.9568
# 01/06/2016           56255.82    38125.0952

# %%
cab.dtypes
# Out:
# Transaction ID      int64
# Date of Travel     object
# Company            object
# City               object
# KM Travelled      float64
# Price Charged     float64
# Cost of Trip      float64
# dtype: object

# %%
city.dtypes
# Out:
# City           object
# Population    float64
# Users         float64
# dtype: object

# %%
customer.dtypes
# Out:
# Customer ID            int64
# Gender                object
# Age                    int64
# Income (USD/Month)     int64
# dtype: object

# %%
transaction.dtypes
# Out:
# Transaction ID     int64
# Customer ID        int64
# Payment_Mode      object
# dtype: object

# %%
Dist_cost=distance_cost.head(50)
Dist_cost.plot()
# Out:
# <AxesSubplot:xlabel='Date of Travel'>

# %%
city.head()
# Out:
#              City   Population      Users
# 0     NEW YORK NY   8,405,837    302,149
# 1      CHICAGO IL   1,955,130    164,468
# 2  LOS ANGELES CA   1,595,037    144,132
# 3        MIAMI FL   1,339,155     17,675
# 4  SILICON VALLEY   1,177,609     27,247

# %%
city.loc[:, ['City', 'Population', 'Users']]
# Out:
#                 City   Population      Users
# 0        NEW YORK NY   8,405,837    302,149
# 1         CHICAGO IL   1,955,130    164,468
# 2     LOS ANGELES CA   1,595,037    144,132
# 3           MIAMI FL   1,339,155     17,675
# 4     SILICON VALLEY   1,177,609     27,247
# 5      ORANGE COUNTY   1,030,185     12,994
# 6       SAN DIEGO CA     959,307     69,995
# 7         PHOENIX AZ     943,999      6,133
# 8          DALLAS TX     942,908     22,157
# 9         ATLANTA GA     814,885     24,701
# 10         DENVER CO     754,233     12,421
# 11         AUSTIN TX     698,371     14,978
# 12        SEATTLE WA     671,238     25,063
# 13         TUCSON AZ     631,442      5,712
# 14  SAN FRANCISCO CA     629,591    213,609
# 15     SACRAMENTO CA     545,776      7,044
# 16     PITTSBURGH PA     542,085      3,643
# 17     WASHINGTON DC     418,859    127,001
# 18      NASHVILLE TN     327,225      9,270
# 19         BOSTON MA     248,968     80,021

# %%
city.iloc[:, [1,2]]
# Out:
#      Population      Users
# 0    8,405,837    302,149
# 1    1,955,130    164,468
# 2    1,595,037    144,132
# 3    1,339,155     17,675
# 4    1,177,609     27,247
# 5    1,030,185     12,994
# 6      959,307     69,995
# 7      943,999      6,133
# 8      942,908     22,157
# 9      814,885     24,701
# 10     754,233     12,421
# 11     698,371     14,978
# 12     671,238     25,063
# 13     631,442      5,712
# 14     629,591    213,609
# 15     545,776      7,044
# 16     542,085      3,643
# 17     418,859    127,001
# 18     327,225      9,270
# 19     248,968     80,021

# %%
city_users=city.groupby(['City'])['Users'].sum()
city_users
# Out:
# City
# ATLANTA GA            24,701
# AUSTIN TX             14,978
# BOSTON MA             80,021
# CHICAGO IL           164,468
# DALLAS TX             22,157
# DENVER CO             12,421
# LOS ANGELES CA       144,132
# MIAMI FL              17,675
# NASHVILLE TN           9,270
# NEW YORK NY          302,149
# ORANGE COUNTY         12,994
# PHOENIX AZ             6,133
# PITTSBURGH PA          3,643
# SACRAMENTO CA          7,044
# SAN DIEGO CA          69,995
# SAN FRANCISCO CA     213,609
# SEATTLE WA            25,063
# SILICON VALLEY        27,247
# TUCSON AZ              5,712
# WASHINGTON DC        127,001
# Name: Users, dtype: object

# %%
city.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        20 non-null     object
#  1   Population  20 non-null     object
#  2   Users       20 non-null     object
# dtypes: object(3)
# memory usage: 608.0+ bytes

# %%
city.head()
# Out:
#              City   Population      Users
# 0     NEW YORK NY   8,405,837    302,149
# 1      CHICAGO IL   1,955,130    164,468
# 2  LOS ANGELES CA   1,595,037    144,132
# 3        MIAMI FL   1,339,155     17,675
# 4  SILICON VALLEY   1,177,609     27,247

# %%
pd.to_numeric(city['Population'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string " 8,405,837 "
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-122-82dbaf805e8a> in <module>
# ----> 1 pd.to_numeric(city['Population'])
#
# ~\anaconda3\lib\site-packages\pandas\core\tools\numeric.py in to_numeric(arg, errors, downcast)
#     152         coerce_numeric = errors not in ("ignore", "raise")
#     153         try:
# --> 154             values = lib.maybe_convert_numeric(
#     155                 values, set(), coerce_numeric=coerce_numeric
#     156             )
#
# pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string " 8,405,837 " at position 0

# %%
city[['Population'].astype(integer)]
city.dtypes()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-130-29eca62a9837> in <module>
# ----> 1 city[['Population'].astype(integer)]
#       2 city.dtypes()
#
# AttributeError: 'list' object has no attribute 'astype'

# %%
city_users.plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-87-5c7ddc50db71> in <module>
# ----> 1 city_users.plot()
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     953                     data.columns = label_name
#     954
# --> 955         return plot_backend.plot(data, kind=kind, **kwargs)
#     956
#     957     __call__.__doc__ = __doc__
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
#     276     def generate(self):
#     277         self._args_adjust()
# --> 278         self._compute_plot_data()
#     279         self._setup_subplots()
#     280         self._make_plot()
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in _compute_plot_data(self)
#     439         # no non-numeric frames or series allowed
#     440         if is_empty:
# --> 441             raise TypeError("no numeric data to plot")
#     442
#     443         self.data = numeric_data.apply(self._convert_to_ndarray)
#
# TypeError: no numeric data to plot

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
company=new['Company']
Total_Profit= new['profit']
ax.bar(company,Total_Profit)
plt.show()

# %% [markdown]
# Plot a line graph showing the linear relationship between kilometers travelled and the price charged per ride for both taxi companies

# %%
#Graph plots
x=new['KM Travelled']
y=new ['Price Charged']
df=(x, y)

#line plots
plt.plot(x,y, color=blue)
plt.legend()
plt.show()
#df=pd.new({new,columns=[KM Travelled], [Price Charged]})

#line plots
#plt.plot([[KM Travelled], [Price Charged], color='blue'])
#plt.legend()
#plt.show()

# %%
#Graph plots
df=pd.new({new,columns=[KM Travelled], [Price Charged]})

#line plots
df.plt.plot([KM Travelled], [Price Charged], color='blue')
plt.legend()
plt.show()

# %%
#df=pd.new({new,columns=[KM Travelled], [Price Charged]})

#line plots
new.plot.line(x='KM Travelled', y='Price Charged', color='blue')
plt.legend()
plt.show()

# %% [markdown]
# Perform a data split for x_test,x_train,y_test and y_train, for purposes of outlier detection, linear regression, training and testing.

# %%
import matplotlib as mpl
line=f('Price Charged={intercept} +{slope}KM Travelled, {r})'
plt.plot(Price Charged, intercept + slope * KM Travelled)
plt.show()

# %% [markdown]
# Statement of hypothesis="KM travelled Affect the price charged by the cabs"
# The above hypothesis is true since the pvalue is 0.

# %%
from sklearn.linear_model import LinearRegression
x= new['KM Travelled']
y=new['Price Charged']
model=scipy.stats.linregress(x, y)
model

# %%
scipy.stats.linRegress(x,y)
y_predict=predict(y)
y_pred

# %% [markdown]
# Statement of null hypothesis: "Cost of trip Affect the price charged by the cabs"

# %%
a= new['Cost of Trip']

model3=scipy.stats.linregress(a,y)
model3

# %%
a= new['Cost of Trip']
z=y-a
d=a+z
model3=scipy.stats.linregress(a,d)
model3

# %%
plt.plot(a,d)
plt.show()

# %% [markdown]
# Statement ofnull hypothesis:"The Customer ID does not affect the price charged by the cabs"
#     The hypothesis was proved true as the pvalue is 0.815832503608265

# %%
b= new['Customer ID']

model4=scipy.stats.linregress(y, b)
model4

# %%
plt.plot(x,y)
plt.show()

# %% [markdown]
# Prediction of price charged, based on cost of trip

# %%
a= new['Cost of Trip']

model2=scipy.stats.linregress(y, a)
model2

# %%
model.slope

# %%
model.intercept

# %%
line='y={intercept} +{slope}x, {r}'
line
plt.show(line)

# %%
df= new[['Date of Travel','Cost of Trip','Price Charged']]
df.head()

# %%
df['Date of Travel']=pd.to_datetime(df['Date of Travel'])  
df.head()

# %%
#df.index=df['Date of Travel']
df.plot()

# %%
cab.corr()
